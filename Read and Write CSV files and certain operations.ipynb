# %%
import pandas as pd
df = pd.read_csv("nyc_weather.csv",header = None, names=["Afroz","Afroz1","Afroz2","Afroz3","Afroz4"])#Giving Heading to My Data If its not mentioned
df
# Out:
#                                                                                      Afroz  \
# EST       Temperature DewPoint Humidity Sea Level PressureIn VisibilityMiles  WindSpeedMPH
# 1/1/2016  38          23       52       30.03                10                          8
# 1/2/2016  36          18       46       30.02                10                          7
# 1/3/2016  40          21       47       29.86                10                          8
# 1/4/2016  25          9        44       30.05                10                          9
# 1/5/2016  20          -3       41       30.57                10                          5
# 1/6/2016  33          4        35       30.5                 10                          4
# 1/7/2016  39          11       33       30.28                10                          2
# 1/8/2016  39          29       64       30.2                 10                          4
# ...

# %%
df = pd.read_csv("nyc_weather.csv",nrows=3)#prints first 3 rows if we have big data
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
# 2               10             8                0           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df = pd.read_csv("nyc_weather.csv",na_values=["-3"])#assigning Not Available value for the data you wanted
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38      23.0        52                 30.03
# 1    1/2/2016           36      18.0        46                 30.02
# 2    1/3/2016           40      21.0        47                 29.86
# 3    1/4/2016           25       9.0        44                 30.05
# 4    1/5/2016           20       NaN        41                 30.57
# 5    1/6/2016           33       4.0        35                 30.50
# 6    1/7/2016           39      11.0        33                 30.28
# 7    1/8/2016           39      29.0        64                 30.20
# 8    1/9/2016           44      38.0        77                 30.16
# 9   1/10/2016           50      46.0        71                 29.59
# 10  1/11/2016           33       8.0        37                 29.92
# 11  1/12/2016           35      15.0        53                 29.85
# 12  1/13/2016           26       4.0        42                 29.94
# ...

# %%
df = pd.read_csv("nyc_weather.csv",na_values={
"DewPoint" :["-3"]
})
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38      23.0        52                 30.03
# 1    1/2/2016           36      18.0        46                 30.02
# 2    1/3/2016           40      21.0        47                 29.86
# 3    1/4/2016           25       9.0        44                 30.05
# 4    1/5/2016           20       NaN        41                 30.57
# 5    1/6/2016           33       4.0        35                 30.50
# 6    1/7/2016           39      11.0        33                 30.28
# 7    1/8/2016           39      29.0        64                 30.20
# 8    1/9/2016           44      38.0        77                 30.16
# 9   1/10/2016           50      46.0        71                 29.59
# 10  1/11/2016           33       8.0        37                 29.92
# 11  1/12/2016           35      15.0        53                 29.85
# 12  1/13/2016           26       4.0        42                 29.94
# ...

# %%
df.to_csv("write.csv")
